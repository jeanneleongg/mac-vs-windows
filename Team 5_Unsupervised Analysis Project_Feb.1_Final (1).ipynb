# %% [markdown]
# <hr style="height:.9px;border:none;color:#333;background-color:#333;" />
# <hr style="height:.9px;border:none;color:#333;background-color:#333;" />
#
# <br><h2>A3 Unsupervised Analysis Project (Team)</h2>
# DAT-5303 | Machine Learning<br><br>
# <strong>FMsBA4 - Team 5</strong><br>
# Bhawesh Parmar<br>
# Diego Cruz<br>
# Jeanne Ron Leong<br>
# Lazza Berhe<br>
# Wenfeng Gu<br><br>
#
# Feb 1, 2021<br>
# Hult International Business School<br><br><br>
#
# <hr style="height:.9px;border:none;color:#333;background-color:#333;" />
# <hr style="height:.9px;border:none;color:#333;background-color:#333;" />

# %% [markdown]
# <br><h2>Overview:</h2><br><br>
#
# This report was conducted with the survey data from the five big personality traits and Hult DNA. The main goal of this study is to understand the purchase behavior between Windows and MacBook users. We will be using the learning techniques to determine similarities among clusters. Both survey answers correspond to a 1-5 scale, 1 implying 'strongly disagree' while 5 to 'strongly agree'. This survey was conducted by 138 students that attend Hult International Business School, varying from 4 different major degree programs. Our analysis will focus mainly on the following demographic data: Ethnicity, Gender, and Type of degree. We will show the correlation between these data types and compare them to their current laptops specific to either Apple or Windows and their willingness to change to the other brand. The overall five big personality survey will determine the following customer buying behavior: 1. Agreeableness 2. Consciousness 3. Extroversion 4. Openness and 5. Stress tolerance. The Hult DNA survey targets behavior skills and cluster students into three main categories: 1. Thinking 2. Communication 3. Team building.  <br><br>
#
# 1.	According to the clusters we found, the willingness to change brands is higher in Windows users. MacBook users are more prone to be loyal to Apple, whereas Windows users will more likely change to Apple. Apple can leverage this to foster a solid brand foundation to deepen customer brand loyalty. In an international crowd, not all personalities are represented by the Big 5. Microsoft is currently losing to Apple in the extroverts market for laptops. There is a group willing to switch from Windows to Mac. This group includes personalities that enjoy being around people, participating in social gatherings, and are full of energy. There is an opportunity for Apple to gain new customers by tapping this niche market with targeted advertising themed around social groups and connections.  <br><br>
#
# 2.	From the data, we found that people who were considered in the 'extraversion' personality cluster were mostly using Windows. This personality group also displayed a higher distribution with the willingness to change brands and buy a MacBook. Combined with that, the Hult DNA personality of people who speaks and listens skillfully had a positive correlation of 0.26 with the willingness to switch brands. Thus, Apple's marketing strategy should target the individuals who are extraverted Windows users as they are most likely to become new MacBook users.<br><br>
#
# 3.	We propose that the 10% discount that Apple offers increase to 15-20%, to be more appealing and more accessible to students. With a higher percentage of students pursuing Dual degree programs using Apple, it would be easier to influence Windows users' conversion in the one-year business analytics program. Besides, with only 8.76% of DD (MBA & Business Analytics) and a higher factor link to a willingness to change laptop, it would be another more specific target segment. <br><br>
#
# <strong>The number of observations:</strong><br> 137 Variables. 37 Variables or Questions belong to 2 surveys: Hult DNA and Big 5 Personality Traits.<br>
# Some questions were double. As a group, we decided to eliminate them from the analysis.<br>
#
# <strong>Importing libraries and Loading Packages</strong><br>
#
# Run the following dictionary to separate survey questions and answers according to survey source and question type.<br>
#
# <strong>Note:</strong> This dictionary also removes duplicate questions from the full dataset. Some duplicated questions were able to identify if respondents were responding thoughtfully as opposed to randomly selecting answers.<br>
#
# <strong>Correlation Analysis.</strong><br>
# The correlation's negative values show us that users are not willing to change to Windows based on their personalities.<br>
#
# <strong>Results for Big Five</strong><br>
# A personality analysis formula had Scored the survey principle components by specific personality.<br>
#
# To make this question more accurate in the survey, we should make it more inclusive and not only binary. As we can see in the results, Females prefer Mac while Males prefer Windows.
# There is a slight difference between some regions regarding Mac and Windows users. However, overall there is no significant difference between the variables. We can see that there is a preference for Windows for Latinos and West Asian Indians, but in Far East Asia and White, there's a preference for Mac.<br>
# <strong>Turnover Analysis.</strong><br>
# Assuming all laptops cost the same. We calculate how many customers are switching from Microsoft to Apple.<br>
#
# <strong>Standardizing the Data.</strong><br>
# The main reason to standardize the data is due a 5 for John could be a 4 for Peter so we basically need to put them in the same level. It helps that we have an standard scale for the survey but this step will make our analysis more accurate.<br>
#
#
# <strong>Data Cleaning. Nationality</strong><br>
# This was a free text answer question. The responses vary between countries, nationalities, and others. We transform the data to all nationalities to be able to analyze it.<br>
#
# <strong>Data Cleaning</strong>. Laptop Used<br>
# This was a free text answer question. The responses vary between countries, nationalities, and others. We transform the data to all nationalities to be able to analyze it.<br>
# <strong>Higher Factors Link to Currently Using a MacBook:<br>
#
# 1.DD (MIB & Business Analytics)
# 2.Neuroticism
# 3.Extraversion
# 4. Inspires Productivity
# 5.Female
# 6. Stay with the same laptop<br>
# <strong>Higher Factors Link to Currently Using a Windows Laptop:</strong><br>
#
# 1.DD (MBA \& Business Analytics)
# 2. One year Business Analytics
# 3.Resolves Conflict Constructively
# 4.Male
# 5. High willingness to change a laptop<br>
#
# <strong>Higher Factors Link to Willingness to Buy a MacBook:</strong><br>
#
# 1.DD (MIB \& Business Analytics)
# 2.Neuroticism
# 3.Extraversion
# 4.Self-Awareness
# 5.Female<br>
# <strong>Higher Factors Link to Willingness to Buy a Windows Laptop:</strong><br>
#
# 1.One year Business Analytics
# 2.Agreeableness
# 3.Resolves Conflict Constructively
# 4.Male<br>
# <strong>Higher Factors Link to Willingness to Change Laptop:</strong><br>
#
# 1.DD (MBA \& Business Analytics)
# 2.Speaks and Listens Skillful
# 3.Self Awareness
# 4.Male<br>
# <strong>Higher Factors Link to Willingness to Stay with current Laptop:</strong><br>
#
# 1.One year  Business Analytics
# 2.Extraversion
# 3. Embraces Change
# 4.Using Windows Laptop currently
# 5.Female<br><br>
#
# To make this question more accurate in the survey, we should make it more inclusive and not only binary. As we can see in the results, Females prefer Mac while Males prefer Windows.<br>
#
# There is a slight difference between some regions regarding Mac and Windows users. However, overall, there is no significant difference between the variables. We can see that there is a preference for Windows for Latinos and West Asian Indians, but in Far East Asia and White, there's a preference for Mac.<br>
#
# Currently, Apple stands at 50.36% of market share (only exclusive to our data) than Windows users of 49.64%. After conducting a thorough analysis of the given dataset, we have found that most respondents are not willing to switch computers. This is most commonly exhibited in Apple users who have been identified with having the most vital brand loyalty. According to the Brand Keys survey in 2020, Apple received the highest brand loyalty rating (Marketing Charts, 2020). In contrast, Windows users tend to show a higher willingness to purchase another brand of laptop. Firstly, we recommend that Apple targets the personality cluster of Openness (big five personalities). In combination with the 'thinking' HULT DNA that makes up 33% of the data. Thus, we can infer that there is a significant market of new potential customers to target. Secondly, our analysis of the dataset showed that Hispanic/ Latino (13.87%) and West Indian (10.95%) respondents were Windows users. According to the global data, Windows users hold a higher market share abroad of 76.42%, while the OS X operating system stands at 16.78% (Statcounter, 2021). This may be attributed to the cost comparison of ownership between a MacBook or Windows laptop. Apple may gain improved market share by increasing promotions such as free air pods or student discounts to attract Windows users. Besides that, since most students are in a first-year Business Analytics program, we recommend that Apple delegates its resources to R\&D to extend their product line to include some products with a lower price.<br>
#
# <strong>References</strong><br>
# 2020's Top Brands Ranked by Customer Loyalty. (2020, October 16). Retrieved February 01, 2021, from https://www.marketingcharts.com/brand-related/brand-loyalty-115053<br>
#
# Desktop Operating System Market Share Worldwide. (n.d.). Retrieved February 01, 2021, from https://gs.statcounter.com/os-market-share/desktop/worldwide/<br>

# %% [markdown]
# <strong>Importing libraries and Loading Packages </strong><br>

# %%
# importing libraries

import pandas as pd                                      # data science essential pandas
import matplotlib.pyplot as plt                          # data visualization
import seaborn as sns                                    # enhaced visualization
from sklearn.preprocessing import StandardScaler         # standard scaler
from sklearn.decomposition import PCA                    # pca
from scipy.cluster.hierarchy import dendrogram, linkage  # dendrogram and linkage
from sklearn.cluster import KMeans                       # kmeans
from sklearn.manifold      import TSNE                   # t-SNE

# loading data

survey = pd.read_excel('./datasets/survey_data.xlsx')

# setting display options
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', 100)

## lowercase the columns name
#survey.columns = survey.columns.str.lower()

survey = survey.drop(['surveyID'],axis = 1)

# checking survey dataset
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 78 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   Am the life of the party                                                      137 non-null    int64
#  1   Feel little concern for others                                                137 non-null    int64
#  2   Am always prepared                                                            137 non-null    int64
#  3   Get stressed out easily                                                       137 non-null    int64
#  4   Have a rich vocabulary                                                        137 non-null    int64
#  5   Don't talk a lot                                                              137 non-null    int64
# ...

# %%
########################################
# pca_plotter
########################################
# optional color scheme
colors_lst = ["#476A2A", "#7851B8", "#BD3430", "#4A2D4E", "#875525",
              "#A83683", "#4E655E", "#853541", "#3A3120", "#535D8E"]


# pca_plotter
def pca_plotter(bunch,
                colors  = None,
                x_label = "First principal component",
                y_label = "Second principal component"):
    """
PARAMETERS
----------
bunch        : Bunch object to be used in PCA
colors       : color coding for target labels, default None
x_label      : x-label for PC 0, default "First principal component"
y_label      : y-label for PC 1, default "Second principal component"
"""

    # INSTANTIATING a PCA object
    pca = PCA(n_components = 2,
              random_state = 219)


    # FITTING and TRANSFORMING the data
    dataset_pca = pca.fit_transform(bunch.data)

    
    # setting figure options
    plt.figure(figsize=(10, 10))
    plt.xlim(dataset_pca[:, 0].min(), dataset_pca[:, 0].max())
    plt.ylim(dataset_pca[:, 1].min(), dataset_pca[:, 1].max())


    # data vizualization
    for i in range(len(bunch.data)):

        plt.text(dataset_pca[i, 0],
                 dataset_pca[i, 1],
                 str(bunch.target[i]),
                 color = colors[bunch.target[i]],
                 fontdict={'weight': 'bold', 'size': 9})

    plt.xlabel(xlabel = x_label)
    plt.ylabel(ylabel = y_label)
    plt.show()

    
########################################
# tsne_plotter
########################################
# optional color scheme
colors_lst = ["#476A2A", "#7851B8", "#BD3430", "#4A2D4E", "#875525",
              "#A83683", "#4E655E", "#853541", "#3A3120", "#535D8E"]


# tsne_plotter
def tsne_plotter(bunch,
                 colors  = None,
                 x_label = "t-SNE feature 0",
                 y_label = "t-SNE feature 1"):
    """
PARAMETERS
----------
bunch        : Bunch object to be used in TSNE
colors       : color coding for target labels, default None
x_label      : x-label for t-SNE feature 0, default "t-SNE feature 0"
y_label      : y-label for t-SNE feature 1, default "t-SNE feature 1"
"""
    
    # INSTANTIATING a PCA object
    tsne = TSNE(random_state = 219)

    
    # FITTING and TRANSFORMING the data
    dataset_tsne = tsne.fit_transform(bunch.data)

    
    # setting figure options
    plt.figure(figsize=(10, 10))
    plt.xlim(dataset_tsne[:, 0].min(), dataset_tsne[:, 0].max() + 1)
    plt.ylim(dataset_tsne[:, 1].min(), dataset_tsne[:, 1].max() + 1)

    
    # data vizualization
    for i in range(len(bunch.data)):

        plt.text(dataset_tsne[i, 0],
                 dataset_tsne[i, 1],
                 str(bunch.target[i]),
                 color    = colors[bunch.target[i]],
                 fontdict = {'weight': 'bold', 'size': 9})

    plt.xlabel(xlabel = x_label)
    plt.ylabel(ylabel = y_label)
    plt.show()

# %%
survey.head(10)
# Out:
#    Am the life of the party  Feel little concern for others  Am always prepared  Get stressed out easily  Have a rich vocabulary  Don't talk a lot  Am interested in people  Leave my belongings around  Am relaxed most of the time  Have difficulty understanding abstract ideas  Feel comfortable around people  Insult people  Pay attention to details  Worry about things  Have a vivid imagination  Keep in the background  Sympathize with others' feelings  Make a mess of things  Seldom feel blue  Am not interested in abstract ideas  Start conversations  Am not interested in other people's problems  Get chores done right away  Am easily disturbed  Have excellent ideas  Have little to say  Have a soft heart  Often forget to put things back in their proper place  Get upset easily  Do not have a good imagination  Talk to a lot of different people at parties  Am not really interested in others  Like order  Change my mood a lot  Am quick to understand things  \
# ...

# %% [markdown]
# <strong>Importing libraries and Loading Packages </strong><br>

# %%
survey.describe()
# Out:
#        Am the life of the party  Feel little concern for others  Am always prepared  Get stressed out easily  Have a rich vocabulary  Don't talk a lot  Am interested in people  Leave my belongings around  Am relaxed most of the time  Have difficulty understanding abstract ideas  Feel comfortable around people  Insult people  Pay attention to details  Worry about things  Have a vivid imagination  Keep in the background  Sympathize with others' feelings  Make a mess of things  Seldom feel blue  Am not interested in abstract ideas  Start conversations  Am not interested in other people's problems  Get chores done right away  Am easily disturbed  Have excellent ideas  Have little to say  Have a soft heart  Often forget to put things back in their proper place  Get upset easily  Do not have a good imagination  Talk to a lot of different people at parties  Am not really interested in others  Like order  Change my mood a lot  Am quick to understand things  \
# ...

# %% [markdown]
# <br>
# Run the following dictionary to separate survey questions and answers according to survey source and question type. <br><br>
#
# <i> Note: This dictionary also removes duplicate questions from the full dataset. Some questions were duplicated to be able to identify if respondents were responding seriously as opposed to randomly selecting answers.</i>

# %%
survey_columns = pd.DataFrame(survey.columns).sort_values(by=0,ascending = True)
survey_columns
# Out:
#                                                                                0
# 2                                                             Am always prepared
# 23                                                           Am easily disturbed
# 47                                                        Am exacting in my work
# 49                                                              Am full of ideas
# 6                                                        Am interested in people
# 19                                           Am not interested in abstract ideas
# 21                                  Am not interested in other people's problems
# 31                                            Am not really interested in others
# 34                                                 Am quick to understand things
# 45                                                     Am quiet around strangers
# 8                                                    Am relaxed most of the time
# ...

# %%
dictionary = {
   'negative': [
        "Don't talk a lot", 
        'Am not interested in abstract ideas',
        "Am not interested in other people's problems",
        'Do not have a good imagination',
        'Am not really interested in others',
        "Don't like to draw attention to myself",
        "Don't mind being the center of attention",
        "Don't  generate ideas that are new and different",
        "Don't persuasively sell a vision or idea",
        "Can't rally people on the team around a common goal"
   ],
    
    'positive': ['Talk a lot',
            'Interested in abstract ideas',
            "Interested in other people's problems",
            'Have a good imagination',
            'Really interested in others',
            "Like to draw attention to myself",
            "Mind being the center of attention",
            "Generate ideas that are new and different",
            "Persuasively sell a vision or idea",
            "Can rally people on the team around a common goal"],
    
    'bigfive': [
        'Am the life of the party',           'Feel little concern for others', 
        'Am always prepared',                 'Get stressed out easily', 
        'Have a rich vocabulary',             "Talk a lot", 
        'Am interested in people',            'Leave my belongings around', 
        'Am relaxed most of the time',        'Have difficulty understanding abstract ideas',
        'Feel comfortable around people',     'Insult people',
        'Pay attention to details',           'Worry about things',
        'Have a vivid imagination',           'Keep in the background', 
        "Sympathize with others' feelings",   'Make a mess of things', 
        'Seldom feel blue',                   'Interested in abstract ideas',
        'Start conversations',                "Interested in other people's problems", 
        'Get chores done right away',         'Am easily disturbed',
        'Have excellent ideas',               'Have little to say',
        'Have a soft heart',                  'Often forget to put things back in their proper place',
        'Get upset easily',                   'Have a good imagination',
        'Really interested in others',        'Talk to a lot of different people at parties',
        'Like order',                         'Change my mood a lot',
        'Am quick to understand things',      "Like to draw attention to myself",
        'Take time out for others',           'Shirk my duties',
        'Have frequent mood swings',          'Use difficult words',
        "Feel others' emotions",              'Follow a schedule',
        'Get irritated easily',               "Mind being the center of attention",
        'Spend time reflecting on things',    'Am quiet around strangers',
        'Make people feel at ease',           'Am exacting in my work', 
        'Often feel blue',                    'Am full of ideas'
    ],
    
    
    'hultdna': [
        'See underlying patterns in complex situations', 
        "Generate ideas that are new and different",
        'Demonstrate an awareness of personal strengths and limitations',
        'Display a growth mindset', 
        'Respond effectively to multiple priorities',
        "Take initiative even when circumstances, objectives, or rules aren't clear", 
        'Encourage direct and open discussions', 
        #'Respond effectively to multiple priorities.1', 
        #"Take initiative even when circumstances, objectives, or rules aren't clear.1",
        #'Encourage direct and open discussions.1', 
        'Listen carefully to others',
        "Persuasively sell a vision or idea",
        'Build cooperative relationships',
        'Work well with people from diverse cultural backgrounds',
        'Effectively negotiate interests, resources, and roles', 
        "Can rally people on the team around a common goal",
        'Translate ideas into plans that are organized and realistic', 
        'Resolve conflicts constructively',
        'Seek and use feedback from teammates',
        'Coach teammates for performance and growth', 
        'Drive for results'],
    
    'demographic' : [
        'What laptop do you currently have?',
        'What laptop would you buy in next assuming if all laptops cost the same?',
        'What program are you in?',
        'What is your age?',
        'Gender',
        'What is your nationality? ',
        'What is your ethnicity?','laptop_change'
        ],
    
    'demographic_new' : ['laptop_use','laptop_to_buy','program','age',
                         'gender','nationality','ethnicity','laptop_change'],
    
    'demographic_dummy':['laptop_change','laptop_use_dummy','laptop_to_buy_dummy',
                         'gender_dummy','DD (MBA & Business Analytics)',
                         'DD (MIB & Business Analytics)','One year Business Analytics'],
    
    'demographic_label':['laptop_use','laptop_to_buy','program','age',
                         'gender','nationality','ethnicity'],
    
    'corr' : [
        'A', 'E', 
        'N', 'C', 'O',
        'What laptop do you currently have?',
        'What laptop would you buy in next assuming if all laptops cost the same?'
        ],
    
    # HULT DNA
    'hult_dna':['self_awareness'
                ,'speaks_listens_skillfull'
                ,'collaboraborative_relationship'
                ,'embraces_change'
                ,'influences_confidently'
                ,'inspires_productivity'
                ,'dynamic_thinking'
                ,'presents_ideas_effectively'
                ,'resolves_conflict_constructively'],

    
    # Five_Factors
    
    'five_factors' : ['Extraversion','Neuroticism','Conscientiousness','Agreeableness','Openness'],
    
    # Extraversion    
    'E' :      ['Am the life of the party',                     'Talk a lot','Keep in the background',         
                'Feel comfortable around people',               'Start conversations',
                'Have little to say',                           'Talk to a lot of different people at parties',
                'Like to draw attention to myself',             'Mind being the center of attention',
                'Am quiet around strangers'],
               

    # Neuroticism
    'N' :      ['Get stressed out easily',                      'Am relaxed most of the time',
                'Worry about things',                           'Seldom feel blue',
                'Am easily disturbed',                          'Get upset easily',
                'Change my mood a lot',                         'Have frequent mood swings',
                'Get irritated easily',                         'Often feel blue'],
               

    # Conscientiousness
    'C' :      ['Am always prepared',                           'Leave my belongings around',
                'Pay attention to details',                     'Make a mess of things', 
                'Get chores done right away',                   'Often forget to put things back in their proper place',
                'Like order',                                   'Shirk my duties',
                'Follow a schedule',                            'Am exacting in my work'], 
               

    # Agreeableness
    'A' :      ['Feel little concern for others',                'Am interested in people',
                'Insult people',                                 "Sympathize with others' feelings",
                "Interested in other people's problems",         'Have a soft heart',
                'Really interested in others',                   'Take time out for others',
                "Feel others' emotions",                         'Make people feel at ease'],
               

    # Openness
    'O' :      ['Have a rich vocabulary',                        'Have difficulty understanding abstract ideas',
                'Have a vivid imagination',                      'Interested in abstract ideas',
                'Have excellent ideas',                          'Have a good imagination',
                'Am quick to understand things',                 'Use difficult words',
                'Spend time reflecting on things',               'Am full of ideas']
    
}

# %%
pd.np.var(survey.loc[:,['Respond effectively to multiple priorities',
        "Take initiative even when circumstances, objectives, or rules aren't clear", 
        'Encourage direct and open discussions', 
        'Respond effectively to multiple priorities.1', 
        "Take initiative even when circumstances, objectives, or rules aren't clear.1",
        'Encourage direct and open discussions.1']])
# Out:
# <ipython-input-7-2304ecb0482a>:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.var(survey.loc[:,['Respond effectively to multiple priorities',
# Respond effectively to multiple priorities                                      0.656934
# Take initiative even when circumstances, objectives, or rules aren't clear      0.839043
# Encourage direct and open discussions                                           0.663754
# Respond effectively to multiple priorities.1                                    0.526400
# Take initiative even when circumstances, objectives, or rules aren't clear.1    0.786403
# Encourage direct and open discussions.1                                         0.597688
# dtype: float64

# %% [markdown]
# <strong>User-defined Functions </strong><br>
# Run the following code to load user-defined functions needed

# %%
#Defining a function to standardize numerical variables in the dataset:
def standard(num_df, by_rows = False):
    """
    This function standardizes a dataframe that contains variables which are either
    integers or floats.
    
    ------
    num_df  : DataFrame, must contain only numerical variables
    by_rows : bool, Default = False. If True, will standardize DataFrame per rows
    
    """
    # INSTANTIATING a StandardScaler() object
    scaler = StandardScaler()

    if by_rows == False:
        # FITTING the scaler
        scaler.fit(num_df)
    
        # TRANSFORMING our data after fit
        scaled = scaler.transform(num_df)
    
        # converting scaled data into a DataFrame
        scaled_df = pd.DataFrame(scaled)
        
        # adding labels to the scaled DataFrame
        scaled_df.columns = num_df.columns
        
        # returning the standardized data frame into the global environment
        return scaled_df
    
    elif by_rows == True:
        
        # Transposing data frame
        transpose_df = num_df.transpose()
        
        # FITTING the scaler
        scaler.fit(transpose_df)
    
        # TRANSFORMING our data after fit
        transposed_scaled = scaler.transform(transpose_df)
        
        # Re-transposing our data frame 
        scaled = transposed_scaled.transpose()
        
        # converting scaled data into a DataFrame
        scaled_df = pd.DataFrame(scaled)
        
        # adding labels to the scaled DataFrame
        scaled_df.columns = num_df.columns
        
        # returning the standardized data frame into the global environment
        return scaled_df
    
    else:
        print('Something went wrong. Please specifiy by_rows argument as True or False.')
        
# scree_plot

def scree_plot(pca_object, export = False):
    # building a scree plot

    # setting plot size
    fig, ax = plt.subplots(figsize=(10, 8))
    features = range(pca_object.n_components_)


    # developing a scree plot
    plt.plot(features,
             pca_object.explained_variance_ratio_,
             linewidth = 2,
             marker = 'o',
             markersize = 10,
             markeredgecolor = 'black',
             markerfacecolor = 'grey')


    # setting more plot options
    plt.title('Scree Plot')
    plt.xlabel('PCA feature')
    plt.ylabel('Explained Variance')
    plt.xticks(features)

    if export == True:
    
        # exporting the plot
        plt.savefig('top_customers_correlation_scree_plot.png')
        
    # displaying the plot
    plt.show()
    
# inertia

def interia_plot(data, max_clust = 50):
    """
PARAMETERS
----------
data      : DataFrame, data from which to build clusters. Dataset should be scaled
max_clust : int, maximum of range for how many clusters to check interia, default 50
    """

    ks = range(1, max_clust)
    inertias = []


    for k in ks:
        # INSTANTIATING a kmeans object
        model = KMeans(n_clusters = k)


        # FITTING to the data
        model.fit(data)


        # append each inertia to the list of inertias
        inertias.append(model.inertia_)
 
    # plotting ks vs inertias
    fig, ax = plt.subplots(figsize = (12, 8))
    plt.plot(ks, inertias, '-o')


    # labeling and displaying the plot
    plt.xlabel('number of clusters, k')
    plt.ylabel('inertia')
    plt.xticks(ks)
    plt.show()

# %% [markdown]
# <strong>Reversing negative scales. </strong><br>
# The way the scale works is,
# 5 = strongly agree,
# 1 = strongly disagree.
# When a question is negative asked we need to reverse the scale to be able to compare all the questions under the same scale. <br>
#
# For example: In the question <i> "Don't mind being the center of attention" </i>, a 5 would be someone who does not like to be the center of attention. <br> By reversing the question to <i> "Mind Being the center of attention" </i> a 5 becomes a 1.

# %%
# Reversing answer scales
survey[dictionary['negative']] = survey[dictionary['negative']].replace(to_replace = [5,4,2,1],
                                                                          value=[1,2,4,5])


positive = ["Talk a lot",
            'Interested in abstract ideas',
            "Interested in other people's problems",
            'Have a good imagination',
            'Really interested in others',
            "Like to draw attention to myself",
            "Mind being the center of attention",
            "Generate ideas that are new and different",
            "Persuasively sell a vision or idea",
            "Can rally people on the team around a common goal"]

# Renaming column questions with positive conotations
survey.rename(columns=dict(zip(dictionary['negative'], positive)), inplace=True)

# %%
# Renaming the demographic variables
survey.rename(columns=dict(zip(dictionary['demographic'], dictionary['demographic_new'])), inplace=True)

# %%
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 78 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   Am the life of the party                                                      137 non-null    int64
#  1   Feel little concern for others                                                137 non-null    int64
#  2   Am always prepared                                                            137 non-null    int64
#  3   Get stressed out easily                                                       137 non-null    int64
#  4   Have a rich vocabulary                                                        137 non-null    int64
#  5   Talk a lot                                                                    137 non-null    int64
# ...

# %%
# Flagging the willingness to change a laptop in new feature 'laptop_change'

survey['laptop_change'] = 0

for index,col in survey.loc[:,['laptop_use','laptop_to_buy']].iterrows():
    if survey.loc[index,'laptop_use'] != survey.loc[index,'laptop_to_buy']:
        survey.loc[index,'laptop_change'] = 1

# %%
# Checking the distribution
survey.loc[: , 'laptop_change'].value_counts()
# Out:
# 0    114
# 1     23
# Name: laptop_change, dtype: int64

# %%
# changing chromebook to windows laptop
survey.loc[: ,'laptop_to_buy'] = survey.loc[: ,'laptop_to_buy'].replace(
                                                                        to_replace = 'Chromebook',
                                                                        value = 'Windows laptop')

# checking results
survey.loc[: , 'laptop_to_buy'].value_counts()
# Out:
# Macbook           77
# Windows laptop    60
# Name: laptop_to_buy, dtype: int64

# %%
# Checking the distribution
survey[['program']].value_counts()
# Out:
# program
# DD (MIB & Business Analytics)       66
# One year Business Analytics         36
# DD (MBA & Business Analytics)       34
# DD (MBA & Disruptive innovation)     1
# dtype: int64

# %%
# Creating dummy variables for categorical variables
survey['laptop_use_dummy'] = 0
survey['laptop_to_buy_dummy'] = 0
survey['gender_dummy'] = 0

# Looping for flagging dummy variables
for index,col in survey.loc[:,['laptop_use']].iterrows():
    if survey.loc[index,'laptop_use'] == 'Macbook':
        survey.loc[index,'laptop_use_dummy'] = 1
        
for index,col in survey.loc[:,['laptop_to_buy']].iterrows():
    if survey.loc[index,'laptop_to_buy'] == 'Macbook':
        survey.loc[index,'laptop_to_buy_dummy'] = 1 
        
for index,col in survey.loc[:,['gender']].iterrows():
    if survey.loc[index,'gender'] == 'Male':
        survey.loc[index,'gender_dummy'] = 1

# %%
# one hot encoding categorical variables
program_dummy = pd.get_dummies(survey['program'])


# joining codings together
survey = survey.join([program_dummy])

# Eliminating 'DD (MBA & Disruptive innovation)' for less observation
survey = survey.drop(['DD (MBA & Disruptive innovation)'],axis = 1)

# %%
survey.head()
# Out:
#    Am the life of the party  Feel little concern for others  Am always prepared  Get stressed out easily  Have a rich vocabulary  Talk a lot  Am interested in people  Leave my belongings around  Am relaxed most of the time  Have difficulty understanding abstract ideas  Feel comfortable around people  Insult people  Pay attention to details  Worry about things  Have a vivid imagination  Keep in the background  Sympathize with others' feelings  Make a mess of things  Seldom feel blue  Interested in abstract ideas  Start conversations  Interested in other people's problems  Get chores done right away  Am easily disturbed  Have excellent ideas  Have little to say  Have a soft heart  Often forget to put things back in their proper place  Get upset easily  Have a good imagination  Talk to a lot of different people at parties  Really interested in others  Like order  Change my mood a lot  Am quick to understand things  Like to draw attention to myself  Take time out for others  \
# ...

# %% [markdown]
# <strong>Data Cleaning. </strong> Nationality
#
# This was a free text answer question. The responses vary between countries, nationalities and others. We transform the data to all nationalities in order to be able to analyze it.

# %%
#change all to lowercase
survey.loc[:,'nationality'] = survey.loc[:,'nationality'].str.lower()


# Standardizing country formatting 
survey.loc[:,'nationality'] = survey.loc[:,'nationality'].replace(
                                                            to_replace = ['india',             'china',          'korea',
                                                                          'korean',            'ecuador',        'taiwan',
                                                                          'usa',               'japan',          'russia',
                                                                          'spain',             'brazil',         'colombia',
                                                                          'republic of korea', 'costarrican',    'mauritius',
                                                                          'cameroon',          'indonesia',      'panama',
                                                                          'germany',           'czech republic', 'nigeria',
                                                                          'canada',            'belgian',        'south korea',
                                                                          'venezuela',         'congolese (dr congo)',
                                                                          'mexico',            'armenia',         'thailand',
                                                                          'dominican republic','philippines',     'peru',
                                                                          'indian.',           'malaysia',        'iran',
                                                                          'english',           'el salvador',     'belarus',
                                                                          'taiwan( r.o.c)',    'costa rica', 'kyrgyz'
                                                                         ],
                                                            value      = ['indian',       'chinese',     'south korean',
                                                                          'south korean', 'ecuadorian',  'taiwanese',
                                                                          'american',     'japanese',    'russian',
                                                                          'spanish',      'brazilian',   'colombian',
                                                                          'south korean', 'costa rican', 'mauritian',
                                                                          'cameroonian',  'indonesian',  'panamanian',
                                                                          'german',       'czech',       'nigerian',
                                                                          'canadian',     'belgian',     'south korean',
                                                                          'venezuelan',   'congolese',   'mexican',
                                                                          'armenian',     'thai',        'dominican',
                                                                          'filipino',     'peruvian',    'indian',
                                                                          'malaysian',    'iranian',     'british',
                                                                          'salvadoran',   'belarusian',  'taiwanese',
                                                                          'costa rican', 'chinese'
                                                                         ])

# Checking results
survey['nationality'].value_counts()
# Out:
# indian                  22
# chinese                 15
# german                   7
# mexican                  6
# peruvian                 6
# american                 6
# brazilian                5
# colombian                5
# russian                  5
# south korean             4
# nigerian                 4
# italian                  3
# indonesian               3
# taiwanese                3
# norwegian                3
# ecuadorian               3
# vietnamese               2
# congolese                2
# thai                     2
# spanish                  2
# canadian                 2
# czech                    2
# turkish                  2
# mauritian                1
# ukrainian                1
# ghanaian                 1
# dominican                1
# british                  1
# filipino                 1
# filipino                 1
# british, indian          1
# pakistani                1
# italian and spanish      1
# costa rican              1
# ...

# %% [markdown]
# <strong>Data Cleaning. </strong> Laptop Used
#
# This was a free text answer question. The responses vary between countries, nationalities and others. We transform the data to all nationalities in order to be able to analyze it.

# %%
# dropping demographic information
purchase_behavior = survey.drop(dictionary['demographic_new'],axis = 1)

# %%
# INSTANTIATING a StandardScaler() object
scaler = StandardScaler()

# FITTING and TRANSFOMRING the scaler with the data

purchases_scaled = pd.DataFrame(scaler.fit_transform(purchase_behavior))

# reattaching column names
purchases_scaled.columns = purchase_behavior.columns


# checking pre- and post-scaling variance
print(np.var(purchase_behavior), '\n\n')
print(np.var(purchases_scaled))
# Out:
# Am the life of the party                                                        1.284458
# Feel little concern for others                                                  1.747669
# Am always prepared                                                              0.845543
# Get stressed out easily                                                         1.469764
# Have a rich vocabulary                                                          0.899142
# Talk a lot                                                                      1.168842
# Am interested in people                                                         0.956790
# Leave my belongings around                                                      1.847515
# Am relaxed most of the time                                                     1.193138
# Have difficulty understanding abstract ideas                                    1.198679
# ...

# %%
# INSTANTIATING a PCA object with no limit to principal components
pca = PCA(n_components = 1,
          random_state = 219)

# FITTING and TRANSFORMING the purchases_scaled by each big five group
bigfive_pca_e = pd.DataFrame(pca.fit_transform(purchases_scaled[dictionary['E']]))
bigfive_pca_n = pd.DataFrame(pca.fit_transform(purchases_scaled[dictionary['N']]))
bigfive_pca_c = pd.DataFrame(pca.fit_transform(purchases_scaled[dictionary['C']]))
bigfive_pca_a = pd.DataFrame(pca.fit_transform(purchases_scaled[dictionary['A']]))
bigfive_pca_o = pd.DataFrame(pca.fit_transform(purchases_scaled[dictionary['O']]))

bigfive_pca = pd.concat([bigfive_pca_e,bigfive_pca_n,bigfive_pca_c,bigfive_pca_a,bigfive_pca_o],axis = 1)

# %%
# Setting columns names to pca df
bigfive_pca.columns = ['Extraversion',
 'Neuroticism',
 'Conscientiousness',
 'Agreeableness',
 'Openness'] 

# Checking the results
bigfive_pca.head()
# Out:
#    Extraversion  Neuroticism  Conscientiousness  Agreeableness  Openness
# 0      0.247940     0.225583          -1.563943       0.998870  0.913974
# 1     -1.597849     0.970292          -0.562403       1.095794 -0.907182
# 2      0.799130    -2.186693          -0.839443       3.758716  1.499580
# 3     -0.753590     1.110389           1.447569      -1.879476 -0.857066
# 4     -0.045109     1.837463           1.756059       1.808173  1.636371

# %%
# FITTING and TRANSFOMRING the scaler with the data

bigfive_pca_scaled = pd.DataFrame(scaler.fit_transform(bigfive_pca))

# reattaching column names
bigfive_pca_scaled.columns = bigfive_pca.columns


# checking pre- and post-scaling variance
print(np.var(bigfive_pca), '\n\n')
print(np.var(bigfive_pca_scaled))
# Out:
# Extraversion         3.867366
# Neuroticism          3.850837
# Conscientiousness    2.944014
# Agreeableness        3.275076
# Openness             3.078637
# dtype: float64
#
#
# Extraversion         1.0
# Neuroticism          1.0
# Conscientiousness    1.0
# Agreeableness        1.0
# Openness             1.0
# dtype: float64

# %%
# INSTANTIATING a PCA object with no limit to principal components
pca_1 = PCA(n_components = 3,
          random_state = 219)

# Subsetting 'hultdna' dataset to hultdna
hultdna = purchases_scaled[dictionary['hultdna']]

# FITTING and TRANSFORMING the hultdna
hultdna_pca = pd.DataFrame(pca_1.fit_transform(hultdna))

# %%
# transposing pca components
factor_loadings_dna = pd.DataFrame(pd.np.transpose(pca_1.components_))


# naming rows as original features
factor_loadings_dna = factor_loadings_dna.set_index(hultdna.columns)


# checking the result
factor_loadings_dna
# Out:
# <ipython-input-26-4c322e821325>:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   factor_loadings_dna = pd.DataFrame(pd.np.transpose(pca_1.components_))
#                                                                                    0         1         2
# See underlying patterns in complex situations                              -0.247655 -0.101048 -0.079963
# Generate ideas that are new and different                                  -0.086460 -0.309537 -0.589897
# Demonstrate an awareness of personal strengths and limitations             -0.240079  0.097363  0.244423
# Display a growth mindset                                                   -0.253540 -0.129131 -0.023490
# Respond effectively to multiple priorities                                 -0.258185 -0.159819  0.332064
# Take initiative even when circumstances, objectives, or rules aren't clear -0.267019 -0.131179  0.229926
# ...

# %%
# reattaching column names
factor_loadings_dna.columns = ['Thinking'
                             ,'Communicating'
                             ,'Team Building'
                            ]         

# checking the result
factor_loadings_dna
# Out:
#                                                                             Thinking  Communicating  Team Building
# See underlying patterns in complex situations                              -0.247655      -0.101048      -0.079963
# Generate ideas that are new and different                                  -0.086460      -0.309537      -0.589897
# Demonstrate an awareness of personal strengths and limitations             -0.240079       0.097363       0.244423
# Display a growth mindset                                                   -0.253540      -0.129131      -0.023490
# Respond effectively to multiple priorities                                 -0.258185      -0.159819       0.332064
# Take initiative even when circumstances, objectives, or rules aren't clear -0.267019      -0.131179       0.229926
# Encourage direct and open discussions                                      -0.269979      -0.214636       0.172763
# ...

# %%
# reattaching column names
hultdna_pca.columns = factor_loadings_dna.columns

hultdna_pca.head()
# Out:
#    Thinking  Communicating  Team Building
# 0  0.087130      -0.288224       0.041347
# 1 -0.124325      -0.248768      -1.926859
# 2  2.690084      -1.608032       0.102125
# 3 -2.297602       2.185935       0.402611
# 4  4.091728       1.237286       1.167390

# %%
# FITTING and TRANSFOMRING the scaler with the data
hultdna_pca_scaled = pd.DataFrame(scaler.fit_transform(hultdna_pca))

# reattaching column names
hultdna_pca_scaled.columns = factor_loadings_dna.columns


# checking pre- and post-scaling variance
print(np.var(hultdna_pca), '\n\n')
print(np.var(hultdna_pca_scaled))
# Out:
# Thinking         6.082960
# Communicating    1.713062
# Team Building    1.186695
# dtype: float64
#
#
# Thinking         1.0
# Communicating    1.0
# Team Building    1.0
# dtype: float64

# %%
interia_plot(data = bigfive_pca_scaled)

# %%
interia_plot(data = hultdna_pca_scaled)

# %%
# Combined bigfive_pca with demographic dummies 
bigfive_full = pd.concat([bigfive_pca,survey[dictionary['demographic_dummy']]],axis = 1)

# %%
# Combined hultdna_pca with demographic dummies 
hultdna_full = pd.concat([hultdna_pca,survey[dictionary['demographic_dummy']]],axis = 1)

# %%
bigfive_full.head()
# Out:
#    Extraversion  Neuroticism  Conscientiousness  Agreeableness  Openness  laptop_change  laptop_use_dummy  laptop_to_buy_dummy  gender_dummy  DD (MBA & Business Analytics)  DD (MIB & Business Analytics)  One year Business Analytics
# 0      0.247940     0.225583          -1.563943       0.998870  0.913974              0                 1                    1             0                              0                              1                            0
# 1     -1.597849     0.970292          -0.562403       1.095794 -0.907182              0                 0                    0             1                              0                              0                            1
# 2      0.799130    -2.186693          -0.839443       3.758716  1.499580              0                 0                    0             1                              0                              0                            1
# ...

# %%
hultdna_full.head()
# Out:
#    Thinking  Communicating  Team Building  laptop_change  laptop_use_dummy  laptop_to_buy_dummy  gender_dummy  DD (MBA & Business Analytics)  DD (MIB & Business Analytics)  One year Business Analytics
# 0  0.087130      -0.288224       0.041347              0                 1                    1             0                              0                              1                            0
# 1 -0.124325      -0.248768      -1.926859              0                 0                    0             1                              0                              0                            1
# 2  2.690084      -1.608032       0.102125              0                 0                    0             1                              0                              0                            1
# ...

# %%
# # Combined bigfive_pca and hultdna_pca with demographic dummies to survey_new
survey_new = pd.concat([survey[dictionary['demographic_dummy']],bigfive_pca,hultdna_pca],axis = 1)

# %%
# grouping data based on Ward distance
standard_mergings_ward_bigfive = linkage(y = bigfive_pca_scaled,
                                 method = 'ward',
                                 optimal_ordering = True)


# setting plot size
fig, ax = plt.subplots(figsize=(12, 12))

# developing a dendrogram
dendrogram(Z = standard_mergings_ward_bigfive,
           leaf_rotation = 90,
           leaf_font_size = 6)


# saving and displaying the plot
plt.savefig('./analysis_images/standard_hierarchical_clust_ward_bigfive.png')
plt.show()

# %%
# grouping data based on Ward distance
standard_mergings_ward_hultdna = linkage(y = hultdna_pca_scaled,
                                 method = 'ward',
                                 optimal_ordering = True)


# setting plot size
fig, ax = plt.subplots(figsize=(12, 12))

# developing a dendrogram
dendrogram(Z = standard_mergings_ward_hultdna,
           leaf_rotation = 90,
           leaf_font_size = 6)


# saving and displaying the plot
plt.savefig('./analysis_images/standard_hierarchical_clust_ward_hultdna.png')
plt.show()

# %%
# INSTANTIATING a k-Means object with clusters
bigfive_k_pca = KMeans(n_clusters   = 3,
                         random_state = 219)


# fitting the object to the data
bigfive_k_pca.fit(bigfive_pca_scaled)


# converting the clusters to a DataFrame
bigfive_kmeans_pca = pd.DataFrame({'cluster_bigfive': bigfive_k_pca.labels_})


# checking the results
print(bigfive_kmeans_pca.iloc[: , 0].value_counts())
# Out:
# 2    59
# 0    42
# 1    36
# Name: cluster_bigfive, dtype: int64

# %%
# renaming cluster
cluster_bigfive_names = {0 : 'personality 1',
                 1 : 'personality 2',
                 2 : 'personality 3'
               }

bigfive_kmeans_pca['cluster_bigfive'].replace(cluster_bigfive_names, inplace = True)

# %%
# INSTANTIATING a k-Means object with clusters
hultdna_k_pca = KMeans(n_clusters   = 3,
                         random_state = 219)


# fitting the object to the data
hultdna_k_pca.fit(hultdna_pca_scaled)


# converting the clusters to a DataFrame
hultdna_kmeans_pca = pd.DataFrame({'cluster_hultdna': hultdna_k_pca.labels_})


# checking the results
print(hultdna_kmeans_pca.iloc[: , 0].value_counts())
# Out:
# 1    54
# 0    43
# 2    40
# Name: cluster_hultdna, dtype: int64

# %%
# renaming cluster
cluster_hultdnae_names = {0 : 'Thinking',
                 1 : 'Communicating',
                 2 : 'Team Building',
               }

hultdna_kmeans_pca['cluster_hultdna'].replace(cluster_hultdnae_names, inplace = True)

# %%
## Combining bigfive cluster and hultdna cluster with full dataset
survey_new = pd.concat([survey_new,bigfive_kmeans_pca,hultdna_kmeans_pca],axis = 1)

# %%
## Combining bigfive cluster and hultdna cluster with full dataset labeled
survey_labeled = pd.concat([survey_new,survey[dictionary['demographic_label']]],axis = 1)

# %%
# Correlation Analysis - Laptop currently use

survey_corr = survey_new.corr(method = 'pearson').round(4)

survey_corr['laptop_use_dummy'].sort_values(ascending = False)
# Out:
# laptop_use_dummy                 1.0000
# laptop_to_buy_dummy              0.7127
# Extraversion                     0.2361
# Neuroticism                      0.2285
# DD (MIB & Business Analytics)    0.2267
# Thinking                         0.0474
# Team Building                    0.0254
# Openness                        -0.0082
# Agreeableness                   -0.0234
# Conscientiousness               -0.0366
# Communicating                   -0.0990
# One year Business Analytics     -0.1039
# DD (MBA & Business Analytics)   -0.1732
# gender_dummy                    -0.1853
# laptop_change                   -0.2181
# Name: laptop_use_dummy, dtype: float64

# %% [markdown]
# <hr style="height:.9px;border:none;color:#333;background-color:#333;" />
#
# <strong>Higher Factors Link to Currently Using a Macbook:</strong><br><br>
# 1.DD (MIB & Business Analytics)<br>
# 2.Neuroticism<br>
# 3.Extraversion<br>
# 4.Female<br>
# 5.Stay with the same laptop<br>
#
# <strong>Higher Factors Link to Currently Using a Windows Laptop:</strong><br><br>
# 1.DD (MBA & Business Analytics)<br>
# 2.One year Business Analytics<br>
# 3.Male<br>
# 4.High willingness to change a laptop<br>
#
# <hr style="height:.9px;border:none;color:#333;background-color:#333;" />

# %%
# Correlation Analysis - Laptop willingness to buy

survey_corr = survey_new.corr(method = 'pearson').round(4)

survey_corr['laptop_to_buy_dummy'].sort_values(ascending = False)
# Out:
# laptop_to_buy_dummy              1.0000
# laptop_use_dummy                 0.7127
# DD (MIB & Business Analytics)    0.2622
# Neuroticism                      0.1304
# Extraversion                     0.1302
# laptop_change                    0.0422
# Communicating                   -0.0062
# Openness                        -0.0289
# Thinking                        -0.0441
# DD (MBA & Business Analytics)   -0.0718
# Conscientiousness               -0.0989
# Team Building                   -0.1117
# gender_dummy                    -0.1141
# Agreeableness                   -0.1750
# One year Business Analytics     -0.2084
# Name: laptop_to_buy_dummy, dtype: float64

# %% [markdown]
# <hr style="height:.9px;border:none;color:#333;background-color:#333;" />
#
# <strong>Higher Factors Link to Willingness to Buy a Macbook:</strong><br><br>
# 1.DD (MIB & Business Analytics)<br>
# 2.Neuroticism<br>
# 3.Extraversion<br>
# 4.Self Awareness<br>
# 5.Female<br>
#
# <strong>Higher Factors Link to Willingness to Buy a Windows Laptop:</strong><br><br>
# 1.One year Business Analytics<br>
# 2.Agreeableness<br>
# 3.Team Building<br>
# 4.Male<br>
#
# <hr style="height:.9px;border:none;color:#333;background-color:#333;" />

# %%
# Correlation Analysis - Laptop willingness to change

survey_corr = survey_new.corr(method = 'pearson').round(4)

survey_corr['laptop_change'].sort_values(ascending = False)
# Out:
# laptop_change                    1.0000
# Communicating                    0.2638
# DD (MBA & Business Analytics)    0.1036
# Conscientiousness                0.0936
# Openness                         0.0792
# gender_dummy                     0.0751
# laptop_to_buy_dummy              0.0422
# Thinking                         0.0059
# Neuroticism                      0.0004
# DD (MIB & Business Analytics)   -0.0031
# Agreeableness                   -0.0396
# Team Building                   -0.0977
# One year Business Analytics     -0.1351
# laptop_use_dummy                -0.2181
# Extraversion                    -0.2380
# Name: laptop_change, dtype: float64

# %% [markdown]
# <hr style="height:.9px;border:none;color:#333;background-color:#333;" />
#
# <strong>Higher Factors Link to Willingness to Change Laptop:</strong><br><br>
# 1.Communication<br>
# 2.DD (MBA & Business Analytics)<br>
# 3.Conscientiousness<br>
# 4.Male<br>
#
# <strong>Higher Factors Link to Willingness to Stay with current Laptop:</strong><br><br>
# 1.Extraversion<br>
# 2.One year Business Analytics<br>
# 3.Team Building<br>
# 4.Using Windows Laptop currently<br>
# 5.Female<br>
#
# <hr style="height:.9px;border:none;color:#333;background-color:#333;" />

# %%
survey_labeled.columns
# Out:
# Index(['laptop_change', 'laptop_use_dummy', 'laptop_to_buy_dummy', 'gender_dummy', 'DD (MBA & Business Analytics)', 'DD (MIB & Business Analytics)', 'One year Business Analytics', 'Extraversion', 'Neuroticism', 'Conscientiousness', 'Agreeableness', 'Openness', 'Thinking', 'Communicating', 'Team Building', 'cluster_bigfive', 'cluster_hultdna', 'laptop_use', 'laptop_to_buy', 'program', 'age', 'gender', 'nationality', 'ethnicity'], dtype='object')

# %%
########################
# laptop_use by bigfives
########################
# setting figure size
fig, ax = plt.subplots(figsize = (20, 30))

plt.subplot(3, 2, 1)

# histogram for master_classes_attended
sns.boxplot(x = 'laptop_use', y='Extraversion', hue = 'cluster_bigfive'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop Use by Personalities",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Extraversion',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)


plt.subplot(3, 2, 2)

# histogram for master_classes_attended
sns.boxplot(x = 'laptop_use', y='Neuroticism', hue = 'cluster_bigfive'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop Use by Personalities",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Neuroticism',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(3, 2, 3)

# histogram for master_classes_attended
sns.boxplot(x = 'laptop_use', y='Conscientiousness', hue = 'cluster_bigfive'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop Use by Personalities",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Conscientiousness',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(3, 2, 4)

# histogram for master_classes_attended
sns.boxplot(x = 'laptop_use', y='Agreeableness', hue = 'cluster_bigfive'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop Use by Personalities",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Agreeableness',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(3, 2, 5)

# histogram for master_classes_attended
sns.boxplot(x = 'laptop_use', y='Openness', hue = 'cluster_bigfive'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop Use by Personalities",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Openness',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.tight_layout()
plt.savefig('./analysis_images/Survey Boxplot1.png')
plt.show()

# %%
########################
# laptop_to_buy by bigfives
########################
# setting figure size
fig, ax = plt.subplots(figsize = (20, 30))

plt.subplot(3, 2, 1)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_to_buy', y='Extraversion', hue = 'cluster_bigfive'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Buy by Personalities",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Extraversion',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)


plt.subplot(3, 2, 2)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_to_buy', y='Neuroticism', hue = 'cluster_bigfive'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Buy by Personalities",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Neuroticism',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(3, 2, 3)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_to_buy', y='Conscientiousness', hue = 'cluster_bigfive'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Buy by Personalities",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Conscientiousness',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(3, 2, 4)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_to_buy', y='Agreeableness', hue = 'cluster_bigfive'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Buy by Personalities",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Agreeableness',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(3, 2, 5)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_to_buy', y='Openness', hue = 'cluster_bigfive'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Buy by Personalities",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Openness',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.tight_layout()
plt.savefig('./analysis_images/Survey Boxplot2.png')
plt.show()

# %%
########################
# laptop_change by bigfives
########################
# setting figure size
fig, ax = plt.subplots(figsize = (20, 30))

plt.subplot(3, 2, 1)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_change', y='Extraversion', hue = 'cluster_bigfive'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Change by Personalities",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Extraversion',fontsize = 12)
plt.xticks([0,1],['Stay','Change'],rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)


plt.subplot(3, 2, 2)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_change', y='Neuroticism', hue = 'cluster_bigfive'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Change by Personalities",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Neuroticism',fontsize = 12)
plt.xticks([0,1],['Stay','Change'],rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(3, 2, 3)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_change', y='Conscientiousness', hue = 'cluster_bigfive'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Change by Personalities",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Conscientiousness',fontsize = 12)
plt.xticks([0,1],['Stay','Change'],rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(3, 2, 4)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_change', y='Agreeableness', hue = 'cluster_bigfive'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Change by Personalities",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Agreeableness',fontsize = 12)
plt.xticks([0,1],['Stay','Change'],rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(3, 2, 5)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_change', y='Openness', hue = 'cluster_bigfive'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Change by Personalities",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Openness',fontsize = 12)
plt.xticks([0,1],['Stay','Change'],rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)


plt.tight_layout()
plt.savefig('./analysis_images/Survey Boxplot3.png')
plt.show()

# %%
########################
# laptop_change by Hult DNA
########################
# setting figure size
fig, ax = plt.subplots(figsize = (20, 22))

plt.subplot(2, 2, 1)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_change', y='Thinking', hue = 'cluster_hultdna'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Change by Hult DNA",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Thinking',fontsize = 12)
plt.xticks([0,1],['Stay','Change'],rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)


plt.subplot(2, 2, 2)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_change', y='Communicating', hue = 'cluster_hultdna'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Change by Hult DNA",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Communicating',fontsize = 12)
plt.xticks([0,1],['Stay','Change'],rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(2, 2, 3)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_change', y='Team Building', hue = 'cluster_hultdna'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Change by Hult DNA",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Team Building',fontsize = 12)
plt.xticks([0,1],['Stay','Change'],rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.tight_layout()
plt.savefig('./analysis_images/Survey Boxplot4.png')
plt.show()

# %%
########################
# laptop_use by Hult DNA
########################
# setting figure size
fig, ax = plt.subplots(figsize = (20, 22))

plt.subplot(2, 2, 1)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_use', y='Thinking', hue = 'cluster_hultdna'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to use by Hult DNA",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Thinking',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)


plt.subplot(2, 2, 2)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_use', y='Communicating', hue = 'cluster_hultdna'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to use by Hult DNA",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Communicating',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(2, 2, 3)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_use', y='Team Building', hue = 'cluster_hultdna'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to use by Hult DNA",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Team Building',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)


plt.tight_layout()
plt.savefig('./analysis_images/Survey Boxplot5.png')
plt.show()

# %%
########################
# laptop_to_buy by Hult DNA
########################
# setting figure size
fig, ax = plt.subplots(figsize = (20, 22))

plt.subplot(2, 2, 1)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_to_buy', y='Thinking', hue = 'cluster_hultdna'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Buy by Hult DNA",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Thinking',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)


plt.subplot(2, 2, 2)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_to_buy', y='Communicating', hue = 'cluster_hultdna'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Buy by Hult DNA",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Communicating',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(2, 2, 3)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_to_buy', y='Team Building', hue = 'cluster_hultdna'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Buy by Hult DNA",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Team Building',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)


plt.tight_layout()
plt.savefig('./analysis_images/Survey Boxplot6.png')
plt.show()

# %%
########################
# laptop_use by program
########################
# setting figure size
fig, ax = plt.subplots(figsize = (20, 30))

plt.subplot(3, 2, 1)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_use', y='Extraversion', hue = 'program'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop Currently Use by Program",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Extraversion',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)


plt.subplot(3, 2, 2)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_use', y='Neuroticism', hue = 'program'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop Currently Use by Program",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Neuroticism',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(3, 2, 3)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_use', y='Conscientiousness', hue = 'program'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop Currently Use by Program",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Conscientiousness',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(3, 2, 4)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_use', y='Agreeableness', hue = 'program'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop Currently Use by Program",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Agreeableness',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(3, 2, 5)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_use', y='Openness', hue = 'program'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop Currently Use by Program",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Openness',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)


plt.tight_layout()
plt.savefig('./analysis_images/Survey Boxplot7.png')
plt.show()

# %%
########################
# laptop_to_buy by program
########################
# setting figure size
fig, ax = plt.subplots(figsize = (20, 30))

plt.subplot(3, 2, 1)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_to_buy', y='Extraversion', hue = 'program'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Buy by Program",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Extraversion',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)


plt.subplot(3, 2, 2)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_to_buy', y='Neuroticism', hue = 'program'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Buy by Program",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Neuroticism',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(3, 2, 3)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_to_buy', y='Conscientiousness', hue = 'program'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Buy by Program",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Conscientiousness',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(3, 2, 4)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_to_buy', y='Agreeableness', hue = 'program'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Buy by Program",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Agreeableness',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(3, 2, 5)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_to_buy', y='Openness', hue = 'program'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Buy by Program",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Openness',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)


plt.tight_layout()
plt.savefig('./analysis_images/Survey Boxplot8.png')
plt.show()

# %%
########################
# laptop_to_buy by program
########################
# setting figure size
fig, ax = plt.subplots(figsize = (20, 30))

plt.subplot(3, 2, 1)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_to_buy', y='Extraversion', hue = 'program'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Buy by Program",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Extraversion',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)


plt.subplot(3, 2, 2)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_to_buy', y='Neuroticism', hue = 'program'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Buy by Program",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Neuroticism',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(3, 2, 3)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_to_buy', y='Conscientiousness', hue = 'program'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Buy by Program",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Conscientiousness',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(3, 2, 4)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_to_buy', y='Agreeableness', hue = 'program'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Buy by Program",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Agreeableness',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(3, 2, 5)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_to_buy', y='Openness', hue = 'program'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Buy by Program",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Openness',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)


plt.tight_layout()
plt.savefig('./analysis_images/Survey Boxplot9.png')
plt.show()

# %%
########################
# laptop_change by program
########################
# setting figure size
fig, ax = plt.subplots(figsize = (20, 30))

plt.subplot(3, 2, 1)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_change', y='Extraversion', hue = 'program'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Change by Program",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Personalities',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)


plt.subplot(3, 2, 2)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_change', y='Neuroticism', hue = 'program'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Change by Program",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Neuroticism',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(3, 2, 3)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_change', y='Conscientiousness', hue = 'program'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Change by Program",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Conscientiousness',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(3, 2, 4)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_change', y='Agreeableness', hue = 'program'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Change by Program",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Agreeableness',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)

plt.subplot(3, 2, 5)

# boxplot for master_classes_attended
sns.boxplot(x = 'laptop_change', y='Openness', hue = 'program'
            , data= survey_labeled ,orient = 'v')


# formatting and displaying the plot
plt.title(label = "Distribution of Laptop to Change by Program",fontsize = 20)
plt.xlabel(xlabel = '',fontsize = 12)
plt.ylabel(ylabel = 'Distribution of Openness',fontsize = 12)
plt.xticks(rotation=45,ha='left',fontsize = 12)
plt.legend(fontsize=12)


plt.tight_layout()
plt.savefig('./analysis_images/Survey Boxplot10.png')
plt.show()

# %% [markdown]
# <strong> Demographic Analysis. </strong> <br>
#
# Analysis of gender for Mac and Windows users.

# %%
# Subsetting Mac users
survey_mac      = survey[survey['laptop_use'] == 'Macbook']

# Subsetting Male users of Mac
survey_mac_male = survey_mac[survey_mac['gender'] == 'Male']
total_male       = survey_mac_male.loc[:,'gender'].value_counts()

# Calculating percent
percent_male_mac =  (total_male / 137) * 100

# Formatting for table
percent_male_mac_print = float(percent_male_mac.round(2))

# Subsetting Female users of Mac
survey_mac_female = survey_mac[survey_mac['gender'] == 'Female']
total_female       = survey_mac_female.loc[:,'gender'].value_counts()

# Calculating percent
percent_female_mac =  (total_female / 137) * 100

# Formatting for table
percent_female_mac_print = float(percent_female_mac.round(2))

# Subsetting users of Windows
survey_windows = survey[survey['laptop_use'] == 'Windows laptop']

# Subsetting Male users of Windows
survey_windows_male = survey_windows[survey_windows['gender'] == 'Male']
total_male_win       = survey_windows_male.loc[:,'gender'].value_counts()

# Calculating percent
percent_male_win =  (total_male_win / 137) * 100

# Formatting for table
percent_male_window_print = float(percent_male_win.round(2))

# Subsetting Female users of Windows
survey_windows_female = survey_windows[survey_windows['gender'] == 'Female']
total_female_win       = survey_windows_female.loc[:,'gender'].value_counts()

# Calculating percent
percent_female_windows =  (total_female_win / 137) * 100

# Formatting for table
percent_female_win_print = float(percent_female_windows.round(2))

# %%
print(f"""
Gender                 % Macbook Users      % Windows Users
-------               ---------------        ----------
Male                     {percent_male_mac_print}                 {percent_male_window_print}

Female                   {percent_female_mac_print}                  {percent_female_win_print}""")
# Out:
# Gender                 % Macbook Users      % Windows Users
# -------               ---------------        ----------
# Male                     24.09                 32.85
#
# Female                   26.28                  16.79

# %% [markdown]
# To make this question in the survey more accurate we should make it more inclusive and not only binary.
# As we can see in the results Females prefer Mac while Males prefer Windows.

# %%
# Subsetting Mac users
survey_mac      = survey[survey['laptop_to_buy'] == 'Macbook']

# Subsetting Male users of Mac
survey_mac_male = survey_mac[survey_mac['gender'] == 'Male']
total_male       = survey_mac_male.loc[:,'gender'].value_counts()

# Calculating percent
percent_male_mac =  (total_male / 137) * 100

# Formatting for table
percent_male_mac_print = float(percent_male_mac.round(2))

# Subsetting Female users of Mac
survey_mac_female = survey_mac[survey_mac['gender'] == 'Female']
total_female       = survey_mac_female.loc[:,'gender'].value_counts()

# Calculating percent
percent_female_mac =  (total_female / 137) * 100

# Formatting for table
percent_female_mac_print = float(percent_female_mac.round(2))

# Subsetting users of Windows
survey_windows = survey[survey['laptop_to_buy'] == 'Windows laptop']

# Subsetting Male users of Windows
survey_windows_male = survey_windows[survey_windows['gender'] == 'Male']
total_male_win       = survey_windows_male.loc[:,'gender'].value_counts()

# Calculating percent
percent_male_win =  (total_male_win / 137) * 100

# Formatting for table
percent_male_window_print = float(percent_male_win.round(2))

# Subsetting Female users of Windows
survey_windows_female = survey_windows[survey_windows['gender'] == 'Female']
total_female_win       = survey_windows_female.loc[:,'gender'].value_counts()

# Calculating percent
percent_female_windows =  (total_female_win / 137) * 100

# Formatting for table
percent_female_win_print = float(percent_female_windows.round(2))

print(f"""
Gender                 % Macbook Users      % Windows Users
-------               ---------------        ----------
Male                     {percent_male_mac_print}                 {percent_male_window_print}

Female                   {percent_female_mac_print}                  {percent_female_win_print}""")
# Out:
# Gender                 % Macbook Users      % Windows Users
# -------               ---------------        ----------
# Male                     29.2                 27.74
#
# Female                   27.01                  16.06

# %% [markdown]
# <strong> Demographic Analysis. </strong> <br>
#
# Analysis of Ethnicity for Mac and Windows users.

# %%
# Subsetting hispanic\latino users of Mac
survey_hispanic_latino_mac = survey_mac[survey_mac['ethnicity'] == 'Hispanic / Latino']
hispanic_latino_mac = survey_hispanic_latino_mac.loc[:,'ethnicity'].value_counts()

# Calculating percent
percent_hispanic_latino_mac = (hispanic_latino_mac / 137) * 100

# Formatting for table
percent_hispanic_latino_print_mac = float(percent_hispanic_latino_mac.round(2))

# Subsetting west asain/indian users of Mac
survey_west_asian_indian_mac = survey_mac[survey_mac['ethnicity'] == 'West Asian / Indian']
west_asian_indian_mac = survey_west_asian_indian_mac.loc[:,'ethnicity'].value_counts()

# Calculating percent
percent_west_asian_indian_mac =  (west_asian_indian_mac / 137) * 100

# Formatting for table
percent_west_asian_indian_print_mac = float(percent_west_asian_indian_mac.round(2))


# Subsetting far east asain of Mac
survey_far_east_asian_mac = survey_mac[survey_mac['ethnicity'] == 'Far east Asian']
far_east_asian_mac = survey_far_east_asian_mac.loc[:,'ethnicity'].value_counts()

# Calculating percent
percent_far_east_asian_mac =  (far_east_asian_mac / 137) * 100

# Formatting for table
percent_far_east_asian_print_mac = float(far_east_asian_mac.round(2))

# Subsetting white/caucasian of Mac
survey_white_caucasian_mac = survey_mac[survey_mac['ethnicity'] == 'White / Caucasian']
white_caucasian_mac = survey_white_caucasian_mac.loc[:,'ethnicity'].value_counts()

# Calculating percent
percent_white_caucasian_mac = (white_caucasian_mac/ 137) * 100

# Formatting for table
percent_white_caucasian_print_mac = float(percent_white_caucasian_mac.round(2))


# Subsetting african/american of Mac
survey_african_american_mac = survey_mac[survey_mac['ethnicity'] == 'African American']
african_american_mac = survey_african_american_mac.loc[:,'ethnicity'].value_counts()

# Calculating percent
percent_african_american_mac  = (african_american_mac / 137) * 100

# Formatting for table
percent_african_american_print_mac = float(percent_african_american_mac.round(2))

# Subsetting prefer not to say of Mac
survey_prefer_not_to_answer_mac = survey_mac[survey_mac['ethnicity'] == 'Prefer not to answer']
prefer_not_to_answer_mac = survey_prefer_not_to_answer_mac.loc[:,'ethnicity'].value_counts()

# Calculating percent
percent_prefer_not_to_answer_mac = (prefer_not_to_answer_mac / 137) * 100

# Formatting for table
percent_prefer_not_to_answer_print_mac = float(percent_prefer_not_to_answer_mac.round(2))


# Subsetting middle eastern of Mac
survey_middle_eastern_mac = survey_mac[survey_mac['ethnicity'] == 'Middle Eastern']
middle_eastern_mac = survey_middle_eastern_mac.loc[:,'ethnicity'].value_counts()

# Calculating percent
percent_middle_eastern_mac =(middle_eastern_mac / 137) * 100

# Formatting for table
percent_middle_eastern_print_mac = float(percent_middle_eastern_mac.round(2))

# Subsetting hispanic\latino users of Windows
survey_hispanic_latino_win = survey_windows[survey_windows['ethnicity'] == 'Hispanic / Latino']
hispanic_latino_win = survey_hispanic_latino_win.loc[:,'ethnicity'].value_counts()

# Calculating percent
percent_hispanic_latino_win = (hispanic_latino_win / 137) * 100

# Formatting for table
percent_hispanic_latino_print_win = float(percent_hispanic_latino_win.round(2))

# Subsetting west asain/indian users of Windows
survey_west_asian_indian_win = survey_windows[survey_windows['ethnicity'] == 'West Asian / Indian']
west_asian_indian_win = survey_west_asian_indian_win.loc[:,'ethnicity'].value_counts()

# Calculating percent
percent_west_asian_indian_win = (west_asian_indian_win / 137) * 100

# Formatting for table
percent_west_asian_indian_print_win = float(percent_west_asian_indian_win.round(2))


# Subsetting far east asain of Windows
survey_far_east_asian_win = survey_windows[survey_windows['ethnicity'] == 'Far east Asian']
far_east_asian_win = survey_far_east_asian_win.loc[:,'ethnicity'].value_counts()

# Calculating percent
percent_far_east_asian_win = (far_east_asian_win / 137) * 100

# Formatting for table
percent_far_east_asian_print_win = float(percent_far_east_asian_win.round(2))

# Subsetting white/caucasian of Windows
survey_white_caucasian_win = survey_windows[survey_windows['ethnicity'] == 'White / Caucasian']
white_caucasian_win = survey_white_caucasian_win.loc[:,'ethnicity'].value_counts()

# Calculating percent
percent_white_caucasian_win = (white_caucasian_win/ 137) * 100

# Formatting for table
percent_white_caucasian_print_win = float(percent_white_caucasian_win.round(2))


# Subsetting african/american of Windows
survey_african_american_win  = survey_windows[survey_windows['ethnicity'] == 'African American']
african_american_win = survey_african_american_win.loc[:,'ethnicity'].value_counts()

# Calculating percent
percent_african_american_win = (african_american_win / 137) * 100

# Formatting for table
percent_african_american_print_win = float(percent_african_american_win.round(2))

# Subsetting prefer not to say of Windows
survey_prefer_not_to_answer_win = survey_windows[survey_windows['ethnicity'] == 'Prefer not to answer']
prefer_not_to_answer_win = survey_prefer_not_to_answer_win.loc[:,'ethnicity'].value_counts()

# Calculating percent
percent_prefer_not_to_answer_win = (prefer_not_to_answer_win / 137) * 100

# Formatting for table
percent_prefer_not_to_answer_print_win = float(percent_prefer_not_to_answer_win.round(2))


# Subsetting middle eastern of Windows
survey_middle_eastern_win = survey_windows[survey_windows['ethnicity'] == 'Middle Eastern']
middle_eastern_win = survey_middle_eastern_win.loc[:,'ethnicity'].value_counts()

# Calculating percent
percent_middle_eastern_win = (middle_eastern_win / 137) * 100

# Formatting for table
percent_middle_eastern_print_win = float(percent_middle_eastern_win.round(2))

print( f"""
Ethnicity                 % Macbook Users      % Windows Users
-------                 ------------------    -----------------
Hispanic/Latino               {percent_hispanic_latino_print_mac}                 {percent_hispanic_latino_print_win}

West Asian Indian             {percent_west_asian_indian_print_mac}                 {percent_west_asian_indian_print_win}

Far East Asian                {percent_far_east_asian_print_mac}                 {percent_far_east_asian_print_win}

White/Caucasian               {percent_white_caucasian_print_mac}                {percent_white_caucasian_print_win}

African_American              {percent_african_american_print_mac}                 {percent_african_american_print_win}

Middle Eastern                {percent_middle_eastern_print_mac}                 {percent_middle_eastern_print_win}

Prefer_not_to_say             {percent_prefer_not_to_answer_print_mac}                 {percent_prefer_not_to_answer_print_win}


""")
# Out:
# Ethnicity                 % Macbook Users      % Windows Users
# -------                 ------------------    -----------------
# Hispanic/Latino               6.57                 11.68
#
# West Asian Indian             8.76                 9.49
#
# Far East Asian                19.0                 7.3
#
# White/Caucasian               17.52                10.22
#
# African_American              4.38                 1.46
#
# Middle Eastern                0.73                 0.73
#
# Prefer_not_to_say             3.65                 2.92

# %% [markdown]
# There is a slightly difference between some regions regarding Mac and Windows users. However in the overall there is no significant difference between the variables. We can see that for Latinos and West Asian Indian there is a preference for Windows but for Far East Asia and White theres a preference for Mac.

# %% [markdown]
# ***
# <strong> Turnover Analysis. </strong><br><br>
# Assuming all laptops cost the same. We calculate how many customers are switching from Microsoft to Apple. <br>

# %%
# WINDOWS
survey_windows      = survey[survey['laptop_use'] == 'Windows laptop']
total_windows        = float(survey_windows.loc[:,'laptop_use'].value_counts())

# Windows to Mac
windows_to_mac       = survey_windows[survey_windows['laptop_to_buy'] == 'Macbook']
total_windows_to_mac = float(windows_to_mac.loc[:,'laptop_to_buy'].value_counts())

# Formatting for table
percent_windows_to_mac = round(((total_windows_to_mac / total_windows) * 100),2)


# Windows to Windows 
windows_to_windows       = survey_windows[survey_windows['laptop_to_buy'] == 'Windows laptop']
total_windows_to_windows = float(windows_to_windows.loc[:,'laptop_to_buy'].value_counts())

# Formatting for table
percent_windows_to_windows = round(((total_windows_to_windows / total_windows) * 100),2)

# MACBOOKS
survey_mac =survey[survey['laptop_use'] == 'Macbook']
total_mac   = float(survey_mac.loc[:,'laptop_use'].value_counts())

# Mac to Mac 
mac_to_mac       = survey_mac [survey_mac['laptop_to_buy'] == 'Macbook']
total_mac_to_mac = float(mac_to_mac.loc[:,'laptop_to_buy'].value_counts())

# Formatting for table
percent_mac_to_mac = round(((total_mac_to_mac / total_mac) * 100),2)


# Mac to Windows
mac_to_windows       = survey_mac[survey_mac['laptop_to_buy'] == 'Windows laptop']
total_mac_to_windows = float(mac_to_windows.loc[:,'laptop_to_buy'].value_counts())

# Formatting for table
percent_mac_to_windows = round(((total_mac_to_windows / total_mac) * 100),2)


print(f"""
                      % To Macbook             % To Windows     
-------               ---------------        --------------     
From Windows          {percent_windows_to_mac}                    {percent_windows_to_windows}                

From Mac              {percent_mac_to_mac}                      {percent_mac_to_windows}                


""")
# Out:
#                       % To Macbook             % To Windows
# -------               ---------------        --------------
# From Windows          20.59                    79.41
#
# From Mac              91.3                      8.7

# %% [markdown]
# Conversion rate to Mac is higher than to Windows.

# %% [markdown]
# ***
# <strong> Requirement Analysis. </strong><br><br>
# Assuming all laptops cost the same. We calculate how many customers are using which brand of laptop depending on their
# requirement and needs. <br>

# %%
# Subsetting mac for dd_mib_ba users
survey_mac_2      = survey[survey['laptop_use'] == 'Macbook']

# Subsetting Male users of Mac
survey_mac_dd_mib_ba = survey_mac_2[survey_mac_2['program'] == 'DD (MIB & Business Analytics)']
total_dd_mib_ba_mac       = survey_mac_dd_mib_ba.loc[:,'program'].value_counts()

# Calculating percent
percent_dd_mib_ba_mac =  (total_dd_mib_ba_mac / 137) * 100

# Formatting for table
percent_dd_mib_ba_mac_print = float(percent_dd_mib_ba_mac.round(2))

# Subsetting Male users of Mac
survey_mac_one_ba = survey_mac_2[survey_mac_2['program'] == 'One year Business Analytics']
total_one_ba_mac       = survey_mac_one_ba.loc[:,'program'].value_counts()

# Calculating percent
percent_one_ba_mac =  (total_one_ba_mac / 137) * 100

# Formatting for table
percent_one_ba_mac_print = float(percent_one_ba_mac.round(2))

# Subsetting mac for dd_mba_ba users
survey_mac_2      = survey[survey['laptop_use'] == 'Macbook']

# Subsetting Male users of Mac
survey_mac_dd_mba_ba = survey_mac_2[survey_mac_2['program'] == 'DD (MBA & Business Analytics)']
total_dd_mba_ba_mac       = survey_mac_dd_mba_ba.loc[:,'program'].value_counts()

# Calculating percent
percent_dd_mba_ba_mac =  (total_dd_mba_ba_mac / 137) * 100

# Formatting for table
percent_dd_mba_ba_mac_print = float(percent_dd_mba_ba_mac.round(2))

# Subsetting mac for dd_mba_di users
survey_mac_2      = survey[survey['laptop_use'] == 'Macbook']

# Subsetting Male users of Mac
survey_mac_dd_mba_di = survey_mac_2[survey_mac_2['program'] == 'DD (MBA & Disruptive innovation)']
total_dd_mba_di_mac       = survey_mac_dd_mba_di.loc[:,'program'].value_counts()

# Calculating percent
percent_dd_mba_di_mac =  (total_dd_mba_di_mac / 137) * 100

# Formatting for table
percent_dd_mba_di_mac_print = float(percent_dd_mba_di_mac.round(2))


# Subsetting users of Windows
survey_windows_2 = survey[survey['laptop_use'] == 'Windows laptop']

# Subsetting Male users of Windows
survey_windows_dd_mib_ba = survey_windows_2[survey_windows_2['program'] == 'DD (MIB & Business Analytics)']
total_dd_mib_ba_win       = survey_windows_dd_mib_ba.loc[:,'program'].value_counts()

# Calculating percent
percent_dd_mib_ba_win =  (total_dd_mib_ba_win / 137) * 100

# Formatting for table
percent_dd_mib_ba_window_print = float(percent_dd_mib_ba_win.round(2))

# Subsetting Male users of Windows
survey_windows_one_ba = survey_windows_2[survey_windows_2['program'] == 'One year Business Analytics']
total_one_ba_win       = survey_windows_one_ba.loc[:,'program'].value_counts()

# Calculating percent
percent_one_ba_win =  (total_one_ba_win / 137) * 100

# Formatting for table
percent_one_ba_window_print = float(percent_one_ba_win.round(2))


# Subsetting Male users of Windows
survey_windows_dd_mba_ba = survey_windows_2[survey_windows_2['program'] == 'DD (MBA & Business Analytics)']
total_dd_mba_ba_win       = survey_windows_dd_mba_ba.loc[:,'program'].value_counts()

# Calculating percent
percent_dd_mba_ba_win =  (total_dd_mba_ba_win / 137) * 100

# Formatting for table
percent_dd_mba_ba_window_print = float(percent_dd_mba_ba_win.round(2))

# Subsetting Male users of Windows
survey_windows_dd_mba_di = survey_windows_2[survey_windows_2['program'] == 'DD (MBA & Disruptive innovation)']
total_dd_mba_di_win       = survey_windows_dd_mba_di.loc[:,'program'].value_counts()

# Calculating percent
percent_dd_mba_di_win =  (total_dd_mba_di_win / 137) * 100

# Formatting for table
percent_dd_mba_di_window_print =  (percent_dd_mba_di_win.round(2))





print( f"""
Program                   % Macbook Users      % Windows Users
-------                 ------------------    -----------------
DD (MIB & Business Analytics)          {percent_dd_mib_ba_mac_print}       {percent_dd_mib_ba_window_print}

One year Business Analytics            {percent_one_ba_mac_print}          {percent_one_ba_window_print}

DD (MBA & Business Analytics)          {percent_dd_mba_ba_mac_print}       {percent_dd_mba_ba_window_print}

DD (MBA & Disruptive innovation)       {percent_dd_mba_di_mac_print}       {0.21}


""")
# Out:
# Program                   % Macbook Users      % Windows Users
# -------                 ------------------    -----------------
# DD (MIB & Business Analytics)          29.93       18.25
#
# One year Business Analytics            10.95          15.33
#
# DD (MBA & Business Analytics)          8.76       16.06
#
# DD (MBA & Disruptive innovation)       0.73       0.21

# %%
survey_labeled.to_excel('./survey_data_analysis.xlsx',index=False)
